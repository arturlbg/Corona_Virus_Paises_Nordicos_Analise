# %%
import pandas as pd
import matplotlib.pyplot as plt


#DINAMARCA
mortes_dinamarca = pd.Series({'60-69':37, '70-79': 126, '80-89': 132, '90+':41}, name="Mortes_dinamarca_idade")

#NORUEGA
mortes_noruega = pd.Series({'60-69':963, '70-79': 339, '80-89': 380, '90+':126}, name="Mortes_noruega_idade")

#SUECIA
mortes_suecia = pd.Series({'60-69':398, '70-79': 1241, '80-89': 2392, '90+':1501}, name="Mortes_suecia_idade")

paises = {'Suécia': mortes_suecia, 'Dinamarca': mortes_dinamarca, 'Noruega':mortes_noruega}

paises_df = pd.DataFrame(paises)
paises_df.plot(kind = 'bar', title='Mortes por covid na faixa etária dos idosos')
