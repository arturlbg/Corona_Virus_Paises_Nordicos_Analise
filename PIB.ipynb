# %%
import pandas as pd
import matplotlib.pyplot as plt

serie_Suecia = pd.Series({'2010':5.2, '2011': 5.8, '2012': 2.7, '2013':2.9, '2014': 0.3, '2015': -3.4, '2016': -5.6, '2017': 1.8, '2018': 2.6, '2019': 2.3,'2020':-4.9}, name="Suecia")

serie_Dinamarca = pd.Series({'2010':1.9, '2011': 1.3, '2012': 0.2, '2013':0.9, '2014': 1.6, '2015': 2.3, '2016': 3.2, '2017': 2, '2018': 2.4, '2019': 2.4,'2020':-6.5}, name="Dinamarca")

serie_Noruega = pd.Series({'2010':0.7, '2011': 1, '2012': 2.7, '2013':1, '2014': 2, '2015': 2, '2016': 1.1, '2017': 2.3, '2018': 1.3, '2019': 1.2,'2020':-6.3}, name="Noruega")

serie_Finlandia = pd.Series({'2010':3.2, '2011': 2.5, '2012': -1.4, '2013':-0.9, '2014': -0.4, '2015': 0.5, '2016': 2.7, '2017': 3.1, '2018': 1.6, '2019': 1,'2020':-6}, name="Finlandia")

serie_Islandia = pd.Series({'2010':-3.4, '2011': 1.9, '2012': 1.3, '2013':4.1, '2014': 2.1, '2015': 4.7, '2016': 6.6, '2017': 4.5, '2018': 3.8, '2019': 1.9,'2020':-7.2}, name="Islandia")

paises_pib = {'Suecia': serie_Suecia, 'Dinamarca': serie_Dinamarca, 'Noruega': serie_Noruega, 'Finlandia': serie_Finlandia, 'Islandia': serie_Islandia}
paises_pib = pd.DataFrame(paises_pib)
paises_pib.plot(kind = 'bar', title='Crescimento do PIB em % desde 2010')
